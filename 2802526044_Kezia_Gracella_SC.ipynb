# %% [markdown]
# <a href="https://colab.research.google.com/github/ttsukkeiii/2802526044---Kezia-Gracella---SC-Lab---BC20/blob/main/2802526044_Kezia_Gracella_SC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2]
y = [1, 3, 2]

f = interp1d(x, y)

y_hat = f(1.5)
print(y_hat)
# Out:
# 2.5

# %%
plt.figure(figsize=(10, 8)) # Ukuran plot 10x8 inchi
plt.plot(x, y, '-ob') # menampilkan tiitk data dengan garis biru dan lingkaran
plt.plot(1.5, y_hat, 'ro') # menampilkan titik hasil interpolasi dengan warna merah
plt.title('Linear Interpolation at x = 1.5') # judul grafik
plt.xlabel('x') # label sumbu x
plt.ylabel('y') # label sumbu y
plt.show() # menampilkan grafik

# %%
import numpy as np
import matplotlib.pyplot as plt

def divided_diff(x, y):
    n = len(y)
    coef = np.zeros([n, n]) # membuat tabel kosong untuk divided differences
    coef[:, 0] = y # kolom pertama berisi nilai y

    for j in range(1, n): # loop untuk mengisi kolom-kolom berikutnya
        for i in range(n - j):
            coef[i][j] = (coef[i + 1][j - 1] - coef[i][j - 1]) / (x[i + j] - x[i])

    return coef
def newton_polly(coef, x_data, x):
    n = len(x_data) - 1
    p = coef[n]

    for k in range(1, n + 1):
        p = coef[n - k] + (x - x_data[n - k]) * p

    return p

# %%
x = np.array([-5, -1, 0, 2])
y = np.array([-2, 6, 1, 3])

# menghitung koefisien divided differences
a_s = divided_diff(x, y)[0, :]

# evaluasi interpolasi pada titik-titik baru
x_new = np.arange(-5, 2.1, .1)
y_new = newton_polly(a_s, x, x_new)

# membuat plot
plt.figure(figsize=(10, 8))
plt.plot(x, y, 'bo') # menampilkan titik data asli
plt.plot(x_new, y_new) # menampilkan kurva interpolasi

# %%
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt

x = [0, 1, 2] # titik data pada sumbu x
y = [1, 3, 2] # titik data pada sumbu y

# membuat fungsi interpolasi kubik dengan batas 'natural'
f = CubicSpline(x, y, bc_type='natural')

# membuat rentang nilai x untuk plot hasil interpolasi
x_new = np.linspace(0, 2, 100) # 100 titik antara 0 dan 2
y_new = f(x_new) # menghitung nilai y menggunakan interpolasi kubik

# membuat plot
plt.figure(figsize=(10, 8)) # ukuran plot 10x8 inchi
plt.plot(x_new, y_new, 'b') # menampilkan kurva interpolasi dalam warna biru
plt.plot(x, y, 'ro') # menampilkan titik data asli dalam warna merah
plt.title('Cubic Spline Interpolation') # judul grafik
plt.xlabel('x') # label sumbu x
plt.ylabel('y') # label sumbu y
plt.show() # menampilkan grafik

# %% [markdown]
# Modul hari ini:

# %%
import numpy as np
from scipy.interpolate import interp1d

# Titik data yang diketahui (jarak dalam meter dan kecepatan dalam m/s)
x = [0, 5, 10]  # Jarak dalam meter
y = [10, 15, 20]  # Kecepatan dalam m/s

# Membuat fungsi interpolasi linear
f = interp1d(x, y, kind='linear')

# Menentukan kecepatan pada jarak 7.2 meter
y_hat = f(7.2)

# Menampilkan hasil
print(f"Kecepatan lari pada jarak 7.2 meter adalah {y_hat:.2f} m/s")
# Out:
# Kecepatan lari pada jarak 7.2 meter adalah 17.20 m/s

# %%
plt.figure(figsize=(10, 8)) # Ukuran plot 10x8 inchi
plt.plot(x, y, '-ob') # menampilkan titik data dengan garis biru dan lingkaran
plt.plot(7.2, y_hat, 'ro') # menampilkan titik hasil interpolasi dengan warna merah
plt.title('Linear Interpolation at x = 7.2') # judul grafik
plt.xlabel('x') # label sumbu x
plt.ylabel('y') # label sumbu y
plt.show() # menampilkan grafik
